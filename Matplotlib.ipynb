# %% [markdown]
# **Prajwal R**
#
# **AMB2175**

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Rainfall_mm'],df['Production_Tons'])
plt.xlabel('Rainfall (mm)')
plt.ylabel('Production (Tons)')
plt.title('Scatter Plot of Rainfall vs Production')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Rainfall vs Production')

# %%
plt.figure(figsize=(8,5))
plt.bar(yearly_production.index,yearly_production,color='skyblue')
plt.xlabel('year')
plt.ylabel('Total production')
plt.title('total crop production per year')
plt.xticks(yearly_production.index)
plt.show()

# %%
yearly_production=df.groupby('Year')['Area_Hectares'].sum()
print(yearly_production)
# Out:
# Year
# 2018    2700
# 2019    2850
# 2020    3000
# 2021    3030
# 2022    3150
# Name: Area_Hectares, dtype: int64

# %%
plt.figure(figsize=(3,3))
plt.bar(yearly_production.index,yearly_production,color='orange')
plt.xlabel('year')
plt.ylabel('Area_Hectares')
plt.title('total area per year')
plt.xticks(yearly_production.index)
plt.show()

# %%
#Filter data for each crop
wheat=df[df['Crop']=='Wheat']
rice=df[df['Crop']=='Rice']
plt.figure()
plt.plot(wheat['Year'],wheat['Production_Tons'],label='Wheat')
plt.plot(rice['Year'],rice['Production_Tons'],label='Rice')
plt.xlabel('Year')
plt.ylabel('Production (Tons)')
plt.title('Crop Production Over Time')
plt.legend()

# %%
data_2022 = df[df['Year']==2022]
plt.figure(figsize=(5,5))
plt.bar(data_2022['Crop'], data_2022['Production_Tons'], color=['orange', 'green'])
plt.xlabel('Crop')
plt.ylabel('Production (Tons)')
plt.title('Crop Production in 2022')
plt.show()

# %%
plt.figure(figsize=(5,5))
bars=plt.bar(yearly_production.index,
             yearly_production.values,
             color='orange',
             edgecolor='black')
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x()+bar.get_width()/2,
            height,
            str(height),
            ha='center',
            va='bottom')
plt.xlabel('Year')
plt.ylabel('Total Production (Tons)')
plt.title('Total Crop Production per Year')
plt.show()

# %%
import matplotlib.pyplot as plt
crop=['Rice','wheat','maize']
size=[10,40,55]
separated=[0.1,0,0]
plt.pie(
    size,
    labels=crop,
    autopct='%1.1f%%',
     shadow=True,
    startangle=90,
    explode=separated
)
plt.title('CROP DISTRIBUTION OF CROPS')
plt.show()

# %%
X=[1,2,3,4,5]
y=[5,3,2,2,1]
plt.xlabel('Years')
plt.ylabel('Values')
plt.title('Line Plot')
plt.plot(X,y)
plt.show()

# %%
X=[1,2,3,4,5]
y=[5,3,2,2,1]
plt.scatter(X,y)
plt.show()

# %%
# Pie Chart
import matplotlib.pyplot as plt
slices = [7,2,2,13]
activities = ['sleeping','eating','working','playing']
cols = ['c','m','r','b']
plt.pie(slices,
 labels=activities,
 colors=cols,
 startangle=90,
 shadow= True,
 explode=(0,0.1,0,0),
 autopct='%1.1f%%')
plt.title('This is a pie chart')
plt.show()

# %%
import matplotlib.pyplot as plt
years=[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
sensex=[17473,20622,15535,19513,21222,27486,26102,26711,34060,36162,41349]
plt.plot(years,sensex)
plt.show()

# %%
years=[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
open_sensex=[17473,20622,15535,19513,21222,27486,26102,26711,34060,36162,41349]
plt.scatter(years,open_sensex)
plt.show

# %%
years=[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
sensex=[17473,20622,15535,19513,21222,27486,26102,26711,34060,36162,41349]
plt.plot(years,sensex)
plt.xlabel('years')
plt.ylabel('sensex')
plt.title('Sensex per year graph')
plt.show

# %%
years=[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
open_sensex=[17473,20622,15535,19513,21222,27486,26102,26711,34060,36162,41349]
close_sensex=[20509,15455,19427,21171,27499,26118,26626,34057,36068,41254,33605]
#execute without legend and label, add one by one
#shape of line should be third parameter
#plt.plot(years,open_sensex,'--',label='open')
plt.plot(years,open_sensex,'--',label='open',marker='o',markerfacecolor='red')
plt.plot(years,close_sensex,label='close')
plt.ylabel("sensex")
plt.xlabel("year")
plt.title("Sensex graph per year")
plt.legend()
plt.grid(True) #true error
plt.show()

# %%
years=[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
open_sensex=[17473,20622,15535,19513,21222,27486,26102,26711,34060,36162,41349]
close_sensex=[20509,15455,19427,21171,27499,26118,26626,34057,36068,41254,33605]
box_plot_data=[open_sensex,close_sensex]
plt.boxplot(box_plot_data)
#plt.boxplot(open_sensex,close_sensex)
plt.show()

# %%
years=[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
open_sensex=[17473,20622,15535,19513,21222,27486,26102,26711,34060,36162,41349]
plt.bar(years,open_sensex,label='opensensex') # Create bars width=0.5
plt.xticks(years)# Create names on the x-axis
plt.ylabel("sensex")
plt.xlabel("year")
plt.title("Sensex graph per year")
plt.legend()
plt.show() # Show

# %%
years=[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
open_sensex=[17473,20622,15535,19513,21222,27486,26102,26711,34060,36162,41349]
close_sensex=[20509,15455,19427,21171,27499,26118,26626,34057,36068,41254,33605]
plt.bar(years,close_sensex,label='closesensex')
plt.bar(years,open_sensex,label='opensensex') # Create bars width=0.5
plt.xticks(years)# Create names on the x-axis
plt.ylabel("sensex")
plt.xlabel("year")
plt.title("Sensex graph per year")
plt.legend()
plt.show() # Show

# %%
import matplotlib.pyplot as plt

open_sensex = [17473, 20622, 15535, 19513, 21222, 27486, 26102, 26711, 34060, 36162, 41349]

# Create histogram
plt.figure(figsize=(8, 6)) # Set the figure size
plt.hist(open_sensex, bins=10, color='orange', edgecolor='black') # Plot the histogram

# Adding titles and labels
plt.title('Histogram of open_sensex')
plt.xlabel('value')
plt.ylabel('Frequency')

# Display the plot
plt.show()
